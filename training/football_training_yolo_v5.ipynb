# %%
##downloaded the data from roboflow
import shutil

shutil.move('football-players-detection-1/train',
            'football-players-detection-1/football-players-detection-1/train')
shutil.move('football-players-detection-1/test',
            'football-players-detection-1/football-players-detection-1/test')
shutil.move('football-players-detection-1/valid',
            'football-players-detection-1/football-players-detection-1/valid')
# Out:
# 'football-players-detection-1/football-players-detection-1/valid'

# %% [markdown]
# # Training

# %%
import torch

device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
from ultralytics import YOLO
#!yolo task = detect mode=train model=yolov5x.pt data=('football-players-detection-1/data.yaml') epochs = 5 imgsz=640
model = YOLO("yolov5l.pt").to(device)

results = model.train(data="football-players-detection-1//data.yaml", epochs = 100, imgsz=640 )
# Out:
# PRO TIP  Replace 'model=yolov5l.pt' with new 'model=yolov5lu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# New https://pypi.org/project/ultralytics/8.3.127 available  Update with 'pip install -U ultralytics'
# ...
